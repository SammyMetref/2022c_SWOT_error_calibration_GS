# %% [markdown]
# ![header](../figures/logos_partenaires._cmems_se.jpg)

# %% [markdown]
# # Comparing multiple SWOT error calibration methods
#
# <div style="text-align: right"><i> 2023-01-13 compare_evaluations </i></div>
#
# ***
# **Authors:**  Datlas, IGE, IMT-Atlantique & CLS <br>
# **Copyright:** 2022 Datlas, IGE, IMT-Atlantique & CLS <br>
# **License:** MIT
#
# <div class="alert alert-block alert-success">
# <h1><center>SWOT calibration comparison</center></h1></div>

# %%
import os
import glob
import sys
sys.path.append('..')
from src.benchmark import *
from src.plot import *
from src.swot import *

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>1. Compare gridbox RMSE</h2>
#
# </div>

# %%
compare_stat('../results/demo_baseline/stat_BASELINE.nc','../results/calib_CERmethod/stat_CERmethod.nc')

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>2. Compare spectral diagnostics</h2>
#
# </div>

# %%
compare_psd(['../results/demo_baseline/psd_BASELINE.nc','../results/calib_CERmethod/psd_CERmethod.nc'],['Baseline','CERmethod'])

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>3. Print summary leaderboard </h2>
#
# </div>

# %%
path_leaderboards = ['../results/demo_baseline/ldb_BASELINE.nc','../results/calib_CERmethod/ldb_CERmethod.nc']
compare_leaderboard(path_leaderboards)
# Out:
# Summary of the leaderboard comparison:
# |   dim_0 | Method   | Field                          |   µ(RMSE) |   λ(SNR1) [km] | Reference   |
# |--------:|:---------|:-------------------------------|----------:|---------------:|:------------|
# |       0 | no calib | SSH [m]                        |  3.3952   |           29.8 |             |
# |       1 | no calib | Geostrophic current [m.s$^-1$] |  9.43752  |           85.5 |             |
# |       2 | no calib | Relative vorticity []          |  0.759946 |           22.7 |             |
# |   dim_0 | Method   | Field                          |   µ(RMSE) |   λ(SNR1) [km] | Reference           |
# |--------:|:---------|:-------------------------------|----------:|---------------:|:--------------------|
# |       0 | BASELINE | SSH [m]                        |  0.145103 |           27.2 | demo_baseline.ipynb |
# |       1 | BASELINE | Geostrophic current [m.s$^-1$] |  0.287818 |           31.2 | demo_baseline.ipynb |
# |       2 | BASELINE | Relative vorticity []          |  0.528865 |           21.9 | demo_baseline.ipynb |
# |   dim_0 | Method    | Field                          |   µ(RMSE) |   λ(SNR1) [km] | Reference             |
# |--------:|:----------|:-------------------------------|----------:|---------------:|:----------------------|
# |       0 | CERmethod | SSH [m]                        | 0.0741071 |            5.6 | calib_CERmethod.ipynb |
# |       1 | CERmethod | Geostrophic current [m.s$^-1$] | 0.219306  |           44.8 | calib_CERmethod.ipynb |
# |       2 | CERmethod | Relative vorticity []          | 0.260702  |          103.2 | calib_CERmethod.ipynb |
