# %% [markdown]
# ![header](../figures/logos_partenaires._cmems_se.jpg)

# %% [markdown]
# # Benchmark SWOT Swath Filtering
#
# <div style="text-align: right"><i> 2022-08-24 CNN_BENCHMARK_DEMO </i></div>
#
# ***
# **Authors:**  CLS & Datlas <br>
# **Copyright:** 2022 CLS & Datlas <br>
# **License:** MIT
#
# <div class="alert alert-block alert-success">
# <h1><center>Benchmark of CNN filter</center></h1></div>

# %% [markdown]
# ***
# **General Note 1**: Execute each cell through the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button from the top MENU (or keyboard shortcut `Shift` + `Enter`).<br>
# <br>
# **General Note 2**: If, for any reason, the kernel is not working anymore, in the top MENU, click on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> button. Then, in the top MENU, click on "Cell" and select "Run All Above Selected Cell".<br>
# ***
#
#
# <div class="alert alert-danger" role="alert">
#
# <h3>Learning outcomes</h3>
#
# At the end of this notebook you will know:
# <ul>
#   <li>How you can display unfiltered, filtered SWOT Level3 SSH products.</li>
#   <li>How you can evaluate the cnn filter: statistical and spectral analysis.</li>
# </ul>
#
# </div>

# %%
import os
import glob
import sys
sys.path.append('..')
from src.benchmark import *
from src.plot import *
from src.swot import *

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>1. Input files to analyse</h2>
#
# </div>

# %% [markdown]
# ## Data challenge inputs

# %%
# Check if inputs have already been downloaded otherwise do
if not os.path.isdir('../dc_inputs'):
    # Get pseuso-observation
    # !wget https://ige-meom-opendap.univ-grenoble-alpes.fr/thredds/fileServer/meomopendap/extract/ocean-data-challenges/2022a_SWOT_karin_error_filtering/dc_inputs.tar.gz
    # !tar -xvf dc_inputs.tar.gz --directory ../
    # !rm -f dc_inputs.tar.gz

# %%
list_of_file_inputs = sorted(glob.glob('../dc_inputs/input_ssh_karin_013*.nc'))

# %% [markdown]
# ## Filtered outputs to evaluate

# %%
list_of_file = sorted(glob.glob('../inputs_local/eNATL60-BLB002/cnn/SWOT_L2_LR_Filtered_013*.nc'))

# %%
if True:
    sshvar = '../inputs_local/eNATL60-BLB002/median/SWOT_L2_LR_Filtered_013_*.nc'
    ds_sshvar = ds_all = xr.open_mfdataset(sshvar,combine='nested',concat_dim='num_lines')

    dist2coast = np.nan_to_num(ds_sshvar.distance_to_nearest_coastline.values, copy=True, nan=0.0)

    inumlines = 0
    ilist_of_file = 0
    for ifile in list_of_file: 

        ds_filt = xr.open_dataset(ifile)
        ssh_filt = ds_filt.ssh_karin_filt.values
        # Masking filtered SWOT under 5km of the coast
        ssh_filt[dist2coast[inumlines:inumlines+ds_filt.time.size]<10] = np.nan

        ds_filt.ssh_karin_filt.values = ssh_filt

        new_ifile = ifile[:-3]+'_10km.nc'

        ds_filt.to_netcdf(new_ifile)

        list_of_file[ilist_of_file] = new_ifile 

        inumlines = inumlines+ds_filt.time.size
        ilist_of_file += 1

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>2. Illustration on one pass (same as quickstart example)</h2>
#
# </div>

# %%
plot_demo_pass(list_of_file_inputs[3], list_of_file[3])

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>3. Statistical & Spectral Analysis </h2>
#
# </div>

# %% [markdown]
# ## 3.1 Parameters

# %%
etuvar = 'ssh_karin_filt'
filter_name = 'CNN_10km'
output_dir = '../results'
stat_output_filename = f'{output_dir}/stat_CNN.nc'
stat_by_regime_output_filename = f'{output_dir}/stat_by_regime_CNN.nc'
psd_output_filename = f'{output_dir}/psd_CNN.nc'
cnn_bench = Benchmark()

# %% [markdown]
# ## 3.2 Compute grid boxes statistics

# %%
# %%time
# Compute gridded stats
cnn_bench.compute_stats(list_of_file, etuvar, list_of_file_inputs)

# Write gridded stats 
cnn_bench.write_stats(stat_output_filename, filter=filter_name)

# Plot gridded stats
cnn_bench.display_stats(stat_output_filename, xlim=(-100, 50), ylim=(0, 80), vmin =0, vmax=0.005)
# Out:
# CPU times: user 1min 11s, sys: 4.8 s, total: 1min 16s
# Wall time: 1min 23s

# %% [markdown]
# ## 3.3 Compute statistics by regime (coastal, offshore low variability, offshore high variability)

# %%
# To speed up computation
# from dask.distributed import Client
# client = Client(n_workers=8, threads_per_worker=8, memory_limit='8GB')

# %%
# %%time 
# Compute stats by regime
cnn_bench.compute_stats_by_regime(list_of_file, etuvar, list_of_file_inputs)

# Write stats by regime
cnn_bench.write_stats_by_regime(stat_by_regime_output_filename, filter=filter_name) 

# Plot stats by regime
cnn_bench.plot_stats_by_regime(stat_by_regime_output_filename)
# Out:
# processing global
# processing coastal
# processing low var
# processing high var
# CPU times: user 6min 16s, sys: 1min 45s, total: 8min 1s
# Wall time: 29min 27s

# %%
#client.close()

# %% [markdown]
# ## 3.4 Compute Spectral scores

# %%
# %%time
# Compute PSD scores
cnn_bench.compute_along_track_psd(list_of_file, etuvar,list_of_file_inputs, lengh_scale=1000)

# Write PSD scores
cnn_bench.write_along_track_psd(psd_output_filename, filter=filter_name)

# Plot PSD scores
cnn_bench.display_psd(psd_output_filename)
# Out:
# CPU times: user 55.4 s, sys: 2.84 s, total: 58.2 s
# Wall time: 2min 7s

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>4. Leaderboard </h2>
#
# </div>

# %%
cnn_bench.summary('demo_benchmark_CNN.ipynb')
# Out:
# Summary of the leaderboard metrics:
# |    | Method        | Field                          |   µ(RMSE global) |   µ(RMSE coastal) |   µ(RMSE offshore lowvar) |   µ(RMSE offshore highvar) |   λ(SNR1) [km] | Reference                |
# |---:|:--------------|:-------------------------------|-----------------:|------------------:|--------------------------:|---------------------------:|---------------:|:-------------------------|
# |  0 | BEFORE FILTER | SSH [m]                        |       0.0129612  |        0.01244    |                0.0130138  |                 0.0140627  |           44.5 | demo_benchmark_CNN.ipynb |
# |  1 | BEFORE FILTER | Geostrophic current [m.s$^-1$] |       0.917187   |        0.801098   |                1.07268    |                 0.545012   |          687.1 | demo_benchmark_CNN.ipynb |
# |  2 | BEFORE FILTER | Relative vorticity []          |      18.1327     |       14.3958     |               22.5588     |                 4.71851    |         1000   | demo_benchmark_CNN.ipynb |
# |  3 | CNN           | SSH [m]                        |       0.00216776 |        0.00233428 |                0.00191651 |                 0.00250264 |           10.5 | demo_benchmark_CNN.ipynb |
# |  4 | CNN           | Geostrophic current [m.s$^-1$] |       0.0545794  |        0.0684147  |                0.0428733  |                 0.050502   |            9.4 | demo_benchmark_CNN.ipynb |
# |  5 | CNN           | Relative vorticity []          |       0.637305   |        0.881635   |                0.475479   |                 0.302517   |           15.4 | demo_benchmark_CNN.ipynb |
